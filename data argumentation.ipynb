# %%
import pandas as pd 
import numpy as np

# %%
df=pd.read_csv("diabetes.csv")
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# 2                       0.672   32        1
# 3                       0.167   21        0
# 4                       2.288   33        1
# ..                        ...  ...      ...
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0
#
# [768 rows x 9 columns]

# %%
import matplotlib.pyplot as plt

plt.scatter(df.iloc[:,7:8],df.iloc[:,-1])

# %%
import seaborn as sns
sns.boxplot (df)
# Out:
# <Axes: >

# %%
# Finding the outliers
df[(df['Insulin'] > 600) | (df['Insulin'] < 0)]
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 13             1      189             60             23      846  30.1
# 228            4      197             70             39      744  36.7
# 247            0      165             90             33      680  52.3
#
#      DiabetesPedigreeFunction  Age  Outcome
# 13                      0.398   59        1
# 228                     2.329   31        0
# 247                     0.427   23        0

# %%
new_df = df[(df['Insulin'] <= 600) & (df['Insulin'] >= 0)]
new_df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# 2                       0.672   32        1
# 3                       0.167   21        0
# 4                       2.288   33        1
# ..                        ...  ...      ...
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0
#
# [765 rows x 9 columns]

# %%
x=df.iloc[:,:-1]
y=df.iloc[:,-1]

# %%
from imblearn.over_sampling import SMOTE

smote = SMOTE(random_state=42,sampling_strategy={0: 1000, 1: 1000})
X_train_resampled, y_train_resampled = smote.fit_resample(x, y)

# %%
X_train_resampled
# Out:
#       Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin        BMI  \
# 0               6      148             72             35        0  33.600000
# 1               1       85             66             29        0  26.600000
# 2               8      183             64              0        0  23.300000
# 3               1       89             66             23       94  28.100000
# 4               0      137             40             35      168  43.100000
# ...           ...      ...            ...            ...      ...        ...
# 1995            2      118             71             30      168  34.267354
# 1996            8       99             68              0        0  31.585831
# 1997           10      149             69             40      269  41.843933
# 1998            4      108             71             30        0  34.229702
# 1999            4      135             84             40       88  35.049805
#
#       DiabetesPedigreeFunction  Age
# 0                     0.627000   50
# 1                     0.351000   31
# 2                     0.672000   32
# 3                     0.167000   21
# 4                     2.288000   33
# ...                        ...  ...
# 1995                  0.221608   33
# 1996                  0.318384   34
# 1997                  0.708874   36
# 1998                  0.248542   27
# 1999                  0.311600   35
#
# [2000 rows x 8 columns]
